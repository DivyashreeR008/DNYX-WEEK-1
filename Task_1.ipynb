# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyashreeR008/DNYX-WEEK-1/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello AI!")
# Out:
# Hello AI!
