# %% [markdown]
# <a href="https://colab.research.google.com/github/DivyashreeR008/DNYX-WEEK-1/blob/main/Task_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
import pandas as pd
df = pd.read_csv('students_data_dirty.csv')
# Out:
#      <input type="file" id="files-21b841ca-6045-411c-85c6-384a0f6eb7c5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21b841ca-6045-411c-85c6-384a0f6eb7c5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(df.head())
print('\n')
print(df.info())
print('\n')
print(df.isnull().sum())
print('\n')
print(df.describe())
# Out:
#    Hours_Studied  Attendance  Gender Parent_Education  Exam_Score
# 0           8.93        63.0  Female       Highschool       88.83
# 4           7.53        69.0   Other          Masters       80.55
# 5           5.51        70.0   Other        Bachelors       32.13
# 6           9.60        87.0  Female       Highschool       82.29
# 7           6.80        67.0   Other       Highschool       36.48
#
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 0 to 44
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Hours_Studied     26 non-null     float64
#  1   Attendance        26 non-null     float64
#  2   Gender            26 non-null     object
#  3   Parent_Education  26 non-null     object
#  4   Exam_Score        26 non-null     float64
# dtypes: float64(3), object(2)
# memory usage: 1.2+ KB
# None
#
#
# Hours_Studied       0
# Attendance          0
# Gender              0
# ...

# %%
df = df.dropna()
df['Exam_Score'] = pd.to_numeric(df['Exam_Score'], errors='coerce')
df = df.drop_duplicates()
print(df)
print('\n')
df.columns = [col.strip().replace(" ", "_") for col in df.columns]
print(df.columns)
# Out:
#     Hours_Studied  Attendance  Gender Parent_Education  Exam_Score
# 0            8.93        63.0  Female       Highschool       88.83
# 4            7.53        69.0   Other          Masters       80.55
# 5            5.51        70.0   Other        Bachelors       32.13
# 6            9.60        87.0  Female       Highschool       82.29
# 7            6.80        67.0   Other       Highschool       36.48
# 9            6.46        81.0   Other       Highschool       82.45
# 13           3.61        84.0  Female        Bachelors       50.08
# 14           6.56        93.0  Female       Highschool       77.41
# 15           4.86        65.0  Female          Masters       34.41
# 16           2.22        96.0   Other          Masters       68.90
# 17           3.68        60.0  Female          Masters       30.65
# 18           6.13        71.0  Female       Highschool       88.31
# 19           6.32        94.0  Female       Highschool       98.90
# ...
